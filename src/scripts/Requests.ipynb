# %%
import requests

# %%
response = requests.get('https://api.github.com/events', verify=False)
print(response.status_code)
print(response.url)
print(response.text)
print(response.json())
# Out:
# c:\Users\je7560\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.github.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 200
# https://api.github.com/events
# ...

# %% [markdown]
# ## Projeto

# %%
import requests

# %% [markdown]
# #### Autenticação

# %%
access_token = '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'
headers = {'Authorization': 'Bearer ' + access_token,
           'X-GitHub-Api-Version': '2022-11-28'}

# %% [markdown]
# #### url da API

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn' # username de quem vamos extrair os dados
url = f'{api_base_url}/users/{owner}/repos'
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %% [markdown]
# #### Paginação

# %% [markdown]
# Extrair os dados de todos os repositórios do usuário de GitHub da Amazon.

# %%
repos_list = []
# Percorre as páginas do repositório da amazon
for page_num in range(1, 6):
    # Tratamento de erro
    try:
        url_page = f'{url}?page={page_num}'
        response = requests.get(url_page, headers=headers,verify=False)
        repos_list.append(response.json())
    # caso ocorra algum erro
    except:
        repos_list.append(None)
# Out:
# c:\Users\je7560\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.github.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\je7560\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.github.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\je7560\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.github.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ...

# %% [markdown]
# #### Nome dos repositórios

# %%
# Acessar o repositorio 3 da pagina 1
repos_list[0][2]['name']
# Out:
# 'ads-advanced-tools-docs'

# %%
respo_name = []
for page in repos_list:
    for repo in page:
        respo_name.append(repo['name'])
len(respo_name)
# Out:
# 150

# %%
# Armazena as linguagens de programação
respo_linguagem = []
for page in repos_list:
    for repo in page:
        respo_linguagem.append(repo['language'])
len(respo_linguagem)

# %% [markdown]
# O dataframe é uma estrutura de dados em forma de tabela que nos permite armazenar e manipular dados utilizando linhas e colunas. Ou seja, o dataframe é uma representação programática de uma tabela.

# %%
import pandas as pd

# %%
dados_amz = pd.DataFrame()
dados_amz["repositorio_name"] = respo_name
dados_amz["language"] = respo_linguagem

# %%
dados_amz.to_csv("amazon.csv")
